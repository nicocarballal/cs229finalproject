# %%
import numpy as np

# %%
month_ = 'apr'
year_ = '2017'
ID_ = '19477309'
# Read in our shapefile for month and year
month_shape = np.load("./../data/United_States_Fires/United_States_{year}_Fires/{month}/multi_day/{ID}.npy".format(month = month_, year = year_, ID = ID_))

# %%
np.sum(month_shape[7])
# Out:
# 278.0

# %%
import matplotlib as mpl
from matplotlib import pyplot

# %%
month_ = 'apr'
year_ = '2017'
ID_ = '19570382'
# Read in our shapefile for month and year
month_shape = np.load("./../data/United_States_Fires/United_States_{year}_Fires/{month}/multi_day/{ID}.npy".format(month = month_, year = year_, ID = ID_))

# make a color map of fixed colors
cmap = mpl.colors.ListedColormap(['green', 'blue', 'red'])
bounds=[-.1, 0.2, .8, 1.1]
norm = mpl.colors.BoundaryNorm(bounds, cmap.N)
# tell imshow about color map so that only set colors are used
prev_shapes = np.zeros(month_shape[0].shape)
for i in range(0, len(month_shape)):
    day_plot = np.zeros(month_shape[i].shape)
    for j in range(len(day_plot)):
        for k in range(len(day_plot[j])):
            if month_shape[i][j][k] == 1:
                day_plot[j][k] = 1
            elif prev_shapes[j][k] > 0:
                day_plot[j][k] = prev_shapes[j][k]
            
    
    img = pyplot.imshow(day_plot,interpolation='nearest',
                    cmap = cmap,norm=norm)
        # make a color bar
    pyplot.colorbar(img,cmap=cmap,
                    norm=norm,boundaries=bounds,ticks=[0,1])

    pyplot.show()
    prev_shapes = 0.5 * np.bitwise_or(prev_shapes > 0, month_shape[i] > 0)
# Out:
# C:\Users\nico\AppData\Local\Temp/ipykernel_22424/2053430891.py:26: MatplotlibDeprecationWarning: The 'cmap' parameter to Colorbar has no effect because it is overridden by the mappable; it is deprecated since 3.3 and will be removed two minor releases later.
#   pyplot.colorbar(img,cmap=cmap,
# C:\Users\nico\AppData\Local\Temp/ipykernel_22424/2053430891.py:26: MatplotlibDeprecationWarning: The 'norm' parameter to Colorbar has no effect because it is overridden by the mappable; it is deprecated since 3.3 and will be removed two minor releases later.
#   pyplot.colorbar(img,cmap=cmap,

# %%
month_ = 'apr'
year_ = '2017'
ID_ = '19570382'
# Read in our shapefile for month and year
month_shape = np.load("./../data/United_States_Fires/United_States_{year}_Fires/{month}/multi_day/{ID}.npy".format(month = month_, year = year_, ID = ID_))

# make a color map of fixed colors
cmap = mpl.colors.ListedColormap(['green', 'blue', 'red'])
bounds=[-.1, 0.2, .8, 1.1]
norm = mpl.colors.BoundaryNorm(bounds, cmap.N)
# tell imshow about color map so that only set colors are used
prev_shapes = np.zeros(month_shape[0].shape)
for i in range(0, len(month_shape)):
    day_plot = np.zeros(month_shape[i].shape)
    for j in range(len(day_plot)):
        for k in range(len(day_plot[j])):
            if month_shape[i][j][k] == 1:
                day_plot[j][k] = 1
            elif prev_shapes[j][k] > 0:
                day_plot[j][k] = prev_shapes[j][k]
            
    
    img = pyplot.imshow(day_plot,interpolation='nearest',
                    cmap = cmap,norm=norm)
        # make a color bar
    pyplot.colorbar(img,cmap=cmap,
                    norm=norm,boundaries=bounds,ticks=[0,1])

    pyplot.show()
    prev_shapes = 0.5 * np.bitwise_or(prev_shapes > 0, month_shape[i] > 0)
# Out:
# C:\Users\nico\AppData\Local\Temp/ipykernel_22424/2053430891.py:26: MatplotlibDeprecationWarning: The 'cmap' parameter to Colorbar has no effect because it is overridden by the mappable; it is deprecated since 3.3 and will be removed two minor releases later.
#   pyplot.colorbar(img,cmap=cmap,
# C:\Users\nico\AppData\Local\Temp/ipykernel_22424/2053430891.py:26: MatplotlibDeprecationWarning: The 'norm' parameter to Colorbar has no effect because it is overridden by the mappable; it is deprecated since 3.3 and will be removed two minor releases later.
#   pyplot.colorbar(img,cmap=cmap,

# %%
month_ = 'dec'
year_ = '2017'
ID_ = '20024064'
# Read in our shapefile for month and year
month_shape = np.load("./../data/United_States_Fires/United_States_{year}_Fires/{month}/multi_day/{ID}.npy".format(month = month_, year = year_, ID = ID_))

# make a color map of fixed colors
cmap = mpl.colors.ListedColormap(['green', 'blue', 'red'])
bounds=[-.1, 0.2, .8, 1.1]
norm = mpl.colors.BoundaryNorm(bounds, cmap.N)
# tell imshow about color map so that only set colors are used
prev_shapes = np.zeros(month_shape[0].shape)
for i in range(0, len(month_shape)):
    day_plot = np.zeros(month_shape[i].shape)
    for j in range(len(day_plot)):
        for k in range(len(day_plot[j])):
            if month_shape[i][j][k] == 1:
                day_plot[j][k] = 1
            elif prev_shapes[j][k] > 0:
                day_plot[j][k] = prev_shapes[j][k]
            
    
    img = pyplot.imshow(day_plot,interpolation='nearest',
                    cmap = cmap,norm=norm)
        # make a color bar
    pyplot.colorbar(img,cmap=cmap,
                    norm=norm,boundaries=bounds,ticks=[0,1])

    pyplot.show()
    prev_shapes = 0.5 * np.bitwise_or(prev_shapes > 0, month_shape[i] > 0)
# Out:
# C:\Users\nico\AppData\Local\Temp/ipykernel_22424/1058215059.py:26: MatplotlibDeprecationWarning: The 'cmap' parameter to Colorbar has no effect because it is overridden by the mappable; it is deprecated since 3.3 and will be removed two minor releases later.
#   pyplot.colorbar(img,cmap=cmap,
# C:\Users\nico\AppData\Local\Temp/ipykernel_22424/1058215059.py:26: MatplotlibDeprecationWarning: The 'norm' parameter to Colorbar has no effect because it is overridden by the mappable; it is deprecated since 3.3 and will be removed two minor releases later.
#   pyplot.colorbar(img,cmap=cmap,
